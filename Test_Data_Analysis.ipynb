# %%
import pandas as pd
import glob
import os

folder_path = "./results_test/"  

# Use glob to find all CSV files in the specified directory
all_files = glob.glob(os.path.join(folder_path, "*.csv"))

# Initialize a list to hold individual dataframe
df_list = []

for file in all_files:
    df = pd.read_csv(file)
    df_list.append(df)

# Concatenate all dataframe into one large dataframe
combined_df = pd.concat(df_list, ignore_index=True)

# Now combined_df holds all the rows from each CSV file
combined_df
# Out:
#                       References               Interventions  Main race  \
# 0           Rickels et al., 2003       paroxetine: 20 mg/day       True
# 1           Rickels et al., 2003       paroxetine: 40 mg/day       True
# 2           Rickels et al., 2003                     placebo       True
# 3       Lenox-Smith et al., 2003  venlafaxine: 75-150 mg/day       True
# 4       Lenox-Smith et al., 2003                     placebo       True
# 5             Boyer et al., 2004      venlafaxine: 75 mg/day       True
# 6             Boyer et al., 2004    venlafaxine: 37.5 mg/day       True
# 7             Boyer et al., 2004     venlafaxine: 150 mg/day       True
# 8             Boyer et al., 2004                     placebo       True
# 9          Merideth et al., 2011      quetiapine: 150 mg/day       True
# 10         Merideth et al., 2011      quetiapine: 300 mg/day       True
# 11         Merideth et al., 2011     escitalopram: 10 mg/day       True
# 12         Merideth et al., 2011                     placebo       True
# 13            Stein et al., 2008   agomelatine: 25-50 mg/day       True
# 14            Stein et al., 2008                     placebo       True
# 15  Mahableshwarkar et al., 2014     vortioxetine: 10 mg/day       True
# 16  Mahableshwarkar et al., 2014    vortioxetine: 2.5 mg/day       True
# 17  Mahableshwarkar et al., 2014      vortioxetine: 5 mg/day       True
# 18  Mahableshwarkar et al., 2014                     placebo       True
# 19  Mahableshwarkar et al., 2014       duloxetine: 60 mg/day       True
# 20      Allgulander et al., 2004   sertraline: 50-150 mg/day       True
# 21      Allgulander et al., 2004                     placebo       True
# 22         Davidson et al., 2004                     placebo       True
# 23         Davidson et al., 2004  escitalopram: 10-20 mg/day       True
# 24            Alaka et al., 2014                     placebo       True
# 25            Alaka et al., 2014   duloxetine: 30-120 mg/day       True
# 26       Nimatoudis et al., 2004  venlafaxine: 75-150 mg/day       True
# 27       Nimatoudis et al., 2004                     placebo       True
# 28             Bose et al., 2008  venlafaxine: 75-225 mg/day       True
# 29             Bose et al., 2008                     placebo       True
# 30             Bose et al., 2008  escitalopram: 10-20 mg/day       True
# 31         Hartford et al., 2007  venlafaxine: 75-225 mg/day       True
# 32         Hartford et al., 2007   duloxetine: 60-120 mg/day       True
# 33         Hartford et al., 2007                     placebo       True
# 34             Ball et al., 2015                     placebo       True
# 35             Ball et al., 2015   duloxetine: 30-120 mg/day       True
# 36          Pollack et al., 2001    paroxetine: 20-50 mg/day       True
# 37          Pollack et al., 2001                     placebo       True
# 38               Wu et al., 2011   duloxetine: 60-120 mg/day       True
# 39               Wu et al., 2011                     placebo       True
# 40           Kasper et al., 2014       paroxetine: 20 mg/day       True
# 41           Kasper et al., 2014          silexan: 80 mg/day       True
# 42           Kasper et al., 2014         silexan: 160 mg/day       True
# 43           Kasper et al., 2014                     placebo       True
# 44             Rynn et al., 2008   duloxetine: 60-120 mg/day       True
# 45             Rynn et al., 2008                     placebo       True
# 46       Rothschild et al., 2012      vortioxetine: 5 mg/day       True
# 47       Rothschild et al., 2012                     placebo       True
# 48             Khan et al., 2011      quetiapine: 150 mg/day       True
# 49             Khan et al., 2011      quetiapine: 300 mg/day       True
# 50             Khan et al., 2011       quetiapine: 50 mg/day       True
# 51             Khan et al., 2011                     placebo       True
#
#     Diagnosis criteria  Sponsor  Sample size  Female (%)  Mean HAMA  \
# 0                 True     True         True        True       True
# 1                 True     True         True        True       True
# 2                 True     True         True        True       True
# 3                 True     True         True        True       True
# 4                 True     True         True        True       True
# 5                 True     True         True        True       True
# 6                 True     True         True        True       True
# 7                 True     True         True        True       True
# 8                 True     True         True        True       True
# 9                 True     True         True        True       True
# 10                True     True         True        True       True
# 11                True     True         True        True       True
# 12                True     True         True        True       True
# 13                True     True         True       False       True
# 14                True     True         True       False       True
# 15                True     True         True        True       True
# 16                True     True         True        True       True
# 17                True     True         True        True       True
# 18                True     True         True        True       True
# 19                True     True         True        True       True
# 20                True     True         True        True       True
# 21                True     True         True        True       True
# 22                True     True         True        True       True
# 23                True     True         True        True       True
# 24                True     True         True        True       True
# 25                True     True         True        True       True
# 26                True    False         True        True       True
# 27                True    False         True        True       True
# 28                True     True         True        True       True
# 29                True     True         True        True       True
# 30                True     True         True        True       True
# 31                True     True         True        True       True
# 32                True     True         True        True       True
# 33                True     True         True        True       True
# 34                True     True         True       False      False
# 35                True     True         True       False      False
# 36                True     True         True        True       True
# 37                True     True         True        True       True
# 38                True     True         True        True       True
# 39                True     True         True        True       True
# 40               False     True         True        True       True
# 41               False     True         True        True       True
# 42               False     True         True        True       True
# 43               False     True         True        True       True
# 44                True     True         True        True       True
# 45                True     True         True        True       True
# 46                True     True         True        True       True
# 47                True     True         True        True       True
# 48                True     True         True        True       True
# 49                True     True         True        True       True
# 50                True     True         True        True       True
# 51                True     True         True        True       True
#
#     Mean age (Year)  Attrition rate (%)  Follow-up time (weeks)
# 0              True                True                    True
# 1              True                True                    True
# 2              True                True                    True
# 3              True                True                    True
# 4              True                True                    True
# 5              True                True                    True
# 6              True                True                    True
# 7              True                True                    True
# 8              True                True                    True
# 9              True                True                    True
# 10             True                True                    True
# 11             True                True                    True
# 12             True                True                    True
# 13            False               False                    True
# 14            False                True                    True
# 15             True               False                   False
# 16             True                True                   False
# 17             True               False                   False
# 18             True                True                   False
# 19             True                True                   False
# 20             True                True                    True
# 21             True                True                    True
# 22             True                True                    True
# 23             True                True                    True
# 24             True                True                    True
# 25             True                True                    True
# 26             True                True                    True
# 27             True                True                    True
# 28             True                True                    True
# 29             True                True                    True
# 30             True                True                    True
# 31             True                True                    True
# 32             True                True                    True
# 33             True                True                    True
# 34            False                True                    True
# 35            False                True                    True
# 36             True                True                    True
# 37             True                True                    True
# 38             True                True                    True
# 39             True                True                    True
# 40             True                True                    True
# 41             True                True                    True
# 42             True                True                    True
# 43             True                True                    True
# 44             True                True                    True
# 45             True                True                    True
# 46             True                True                    True
# 47             True                True                    True
# 48             True               False                   False
# 49             True               False                   False
# 50             True               False                   False
# 51             True               False                   False

# %%
import pandas as pd

# Create a new column that indicates if at least one metric is True in that row
# If all selected columns are False, this will be False otherwise True
bool_columns = [col for col in combined_df.columns 
                if col not in ['References', 'Interventions']]
combined_df["Interventions_Binary"] = combined_df[bool_columns].any(axis=1)
# Identify the columns that have True/False values. 
bool_columns = [col for col in combined_df.columns 
                if col not in ['References', 'Interventions']]

print(f"Testing Accuracy Metrics:")

# Calculate and print accuracy (proportion of True values) for each boolean column
for col in bool_columns:
    accuracy = combined_df[col].mean()  # mean of True/False gives proportion True
    print(f"{col}: {accuracy:.2f}")

# Calculate overall accuracy across all boolean metrics
overall_accuracy = combined_df[bool_columns].values.mean()
print(f"Overall accuracy for all metrics: {overall_accuracy:.2f}")
# Out:
# Testing Accuracy Metrics:
# Main race: 1.00
# Diagnosis criteria: 0.92
# Sponsor: 0.96
# Sample size: 1.00
# Female (%): 0.92
# Mean HAMA: 0.96
# Mean age (Year): 0.92
# Attrition rate (%): 0.87
# Follow-up time (weeks): 0.83
# Interventions_Binary: 1.00
# Overall accuracy for all metrics: 0.94

# %% [markdown]
# # NA Scoring

# %%
from openpyxl import load_workbook

file_path = './truth_excel/test_all_studies_final.xlsx'
workbook = load_workbook(file_path)
sheet = workbook.active

# Convert to DataFrame
data = sheet.values
columns = next(data)
df_truth = pd.DataFrame(data, columns=columns)

# %%
df_truth
# Out:
#                       References  Sample size               Interventions  \
# 0       Lenox-Smith et al., 2003          244  Venlafaxine: 75-150 mg/day
# 1       Lenox-Smith et al., 2003          244                     Placebo
# 2   Mahableshwarkar et al., 2014          781    Vortioxetine: 2.5 mg/day
# 3   Mahableshwarkar et al., 2014          781      Vortioxetine: 5 mg/day
# 4   Mahableshwarkar et al., 2014          781     Vortioxetine: 10 mg/day
# ..                           ...          ...                         ...
# 77            Coric et al., 2010          260                     Placebo
# 78             Rynn et al., 2008          327   Duloxetine: 60-120 mg/day
# 79             Rynn et al., 2008          327                     Placebo
# 80          Pollack et al., 2001          324    Paroxetine: 20-50 mg/day
# 81          Pollack et al., 2001          324                     Placebo
#
#     Main race Female (%) Mean HAMA Mean age (Year) Attrition rate (%)  \
# 0          NA       61.5        28              48               12.3
# 1          NA       56.6        28              46               20.5
# 2       White       69.9      25.3            39.2               23.1
# 3       White       64.1        25            37.7                 25
# 4       White       67.3      25.3            39.8               28.8
# ..        ...        ...       ...             ...                ...
# 77      White        100      24.7            39.3               23.1
# 78  Caucasian       61.3      22.6            42.2               44.6
# 79  Caucasian       62.3      23.5              41               31.4
# 80      White       60.9      24.2            39.7               21.1
# 81      White       66.3      24.1            41.3               18.4
#
#             Sponsor  Follow-up time (weeks) Diagnosis criteria
# 0             Wyeth                      24             DSM-IV
# 1             Wyeth                      24             DSM-IV
# 2            Takeda                       8             DSM-IV
# 3            Takeda                       8             DSM-IV
# 4            Takeda                       8             DSM-IV
# ..              ...                     ...                ...
# 77    Bristol-Myers                       8             DSM-IV
# 78        Eli Lilly                      10             DSM-IV
# 79        Eli Lilly                      10             DSM-IV
# 80  GlaxoSmithKline                       8             DSM-IV
# 81  GlaxoSmithKline                       8             DSM-IV
#
# [82 rows x 11 columns]

# %%
import pandas as pd
import numpy as np

# Exclude non-boolean columns
bool_columns = [col for col in combined_df.columns 
                if col not in ['References', 'Interventions', 'Any_True', 'Interventions_Binary']]

# Step 1: Filter rows where df_truth has the string "NA" in relevant columns
na_mask = df_truth[bool_columns] == "NA"  
na_rows_mask = na_mask.any(axis=1)     

if na_rows_mask.sum() > 0:
    filtered_df_truth = df_truth.loc[na_rows_mask, bool_columns]
    filtered_combined_df = combined_df.loc[na_rows_mask, bool_columns]

    print("Accuracy metrics for 'NA' rows (by column):\n")
    
    # Step 2: Calculate column-wise accuracy
    for col in bool_columns:
        col_mask = na_mask[col] 
        total_na = col_mask.sum()

        if total_na > 0: 
            true_count = filtered_combined_df.loc[col_mask, col].sum()
            accuracy = true_count / total_na
            print(f"{col}: {accuracy:.2f} (NA count: {total_na})")
        else:
            print(f"{col}: No NA values")
    predicted_for_na = combined_df[bool_columns][na_mask]  # Only predictions where truth == "NA"

    # Step 3: Overall accuracy for NA-specific cells
    total_na_cells = na_mask.sum().sum()  # Total number of NA cells in df_truth
    correct_predictions = predicted_for_na.sum().sum()  # Sum of True predictions where truth == "NA"
    
    if total_na_cells > 0:
        overall_accuracy_na = correct_predictions / total_na_cells
        print(f"\nOverall accuracy for predicting 'NA' values: {overall_accuracy_na:.2f}")
# Out:
# Accuracy metrics for 'NA' rows (by column):
#
# Main race: 0.70 (NA count: 20)
# Diagnosis criteria: No NA values
# Sponsor: 0.00 (NA count: 2)
# Sample size: No NA values
# Female (%): 0.83 (NA count: 12)
# Mean HAMA: 0.80 (NA count: 10)
# Mean age (Year): 0.83 (NA count: 12)
# Attrition rate (%): 0.40 (NA count: 10)
# Follow-up time (weeks): No NA values
#
# Overall accuracy for predicting 'NA' values: 0.70
